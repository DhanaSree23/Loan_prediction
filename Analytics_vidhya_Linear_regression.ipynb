# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('train_ctrUa4K.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
data.replace('3+', '3', inplace=True)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
loan_data=data['Loan_ID']
data.drop("Loan_ID",axis=1,inplace=True)
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes          3      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# 3           Urban           Y
# 4           Urban           Y
# ..            ...         ...
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# 613     Semiurban           N
#
# [614 rows x 12 columns]

# %%
loan_data
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cat=data.select_dtypes(include='object').columns
num=data.select_dtypes(exclude='object').columns

cat
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data["Gender"]=data["Gender"].fillna(data["Gender"].mode()[0])
data["Married"]=data["Married"].fillna(data["Married"].mode()[0])
data["Dependents"]=data["Dependents"].fillna(data["Dependents"].mode()[0])
data["Education"]=data["Education"].fillna(data["Education"].mode()[0])
data["Self_Employed"]=data["Self_Employed"].fillna(data["Self_Employed"].mode()[0])
data["Property_Area"]=data["Property_Area"].fillna(data["Property_Area"].mode()[0])

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
num
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data["LoanAmount"]=data["LoanAmount"].fillna(data["LoanAmount"].mean())
data["Loan_Amount_Term"]=data["Loan_Amount_Term"].fillna(data["Loan_Amount_Term"].mean())
data["Credit_History"]=data["Credit_History"].fillna(data["Credit_History"].mean())

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
for i in cat:
    unique=data[i].unique()
    print(f'{i} : {unique}')
# Out:
# Gender : ['Male' 'Female']
# Married : ['No' 'Yes']
# Dependents : ['0' '1' '2' '3']
# Education : ['Graduate' 'Not Graduate']
# Self_Employed : ['No' 'Yes']
# Property_Area : ['Urban' 'Rural' 'Semiurban']
# Loan_Status : ['Y' 'N']

# %%
d={'Male':1,'Female':0}
data['Gender']=data['Gender'].map(d)
d={'Yes':1,'No':0}
data['Married']=data['Married'].map(d)
d={'0':0,'1':1,'2':2,'3':3}
data['Dependents']=data['Dependents'].map(d)
d={'Graduate':1,'Not Graduate':0}
data['Education']=data['Education'].map(d)
d={'Yes':1,'No':0}
data['Self_Employed']=data['Self_Employed'].map(d)
d={'Urban':2,'Rural':0,'Semiurban':1}
data['Property_Area']=data['Property_Area'].map(d)

# %%
d={'Y':1,'N':0}
data['Loan_Status']=data['Loan_Status'].map(d)

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0   71.000000             360.0             1.0
# 610                0.0   40.000000             180.0             1.0
# 611              240.0  253.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
#      Property_Area  Loan_Status
# 0                2            1
# 1                0            0
# 2                2            1
# 3                2            1
# 4                2            1
# ..             ...          ...
# 609              0            1
# 610              0            1
# 611              2            1
# 612              2            1
# 613              1            0
#
# [614 rows x 12 columns]

# %%
X=data.drop('Loan_Status',axis=1)
y=data['Loan_Status']
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0   71.000000             360.0             1.0
# 610                0.0   40.000000             180.0             1.0
# 611              240.0  253.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
#      Property_Area
# 0                2
# 1                0
# 2                2
# 3                2
# 4                2
# ..             ...
# 609              0
# 610              0
# 611              2
# 612              2
# 613              1
#
# [614 rows x 11 columns]

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0   71.000000             360.0             1.0
# 610                0.0   40.000000             180.0             1.0
# 611              240.0  253.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
#      Property_Area
# 0                2
# 1                0
# 2                2
# 3                2
# 4                2
# ..             ...
# 609              0
# 610              0
# 611              2
# 612              2
# 613              1
#
# [614 rows x 11 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
ss=StandardScaler()
X_scaled=ss.fit_transform(X)
X_scaled_df=pd.DataFrame(X_scaled,columns=X.columns)
X_scaled_df
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.472343 -1.372089   -0.737806   0.528362      -0.392601
# 1    0.472343  0.728816    0.253470   0.528362      -0.392601
# 2    0.472343  0.728816   -0.737806   0.528362       2.547117
# 3    0.472343  0.728816   -0.737806  -1.892641      -0.392601
# 4    0.472343 -1.372089   -0.737806   0.528362      -0.392601
# ..        ...       ...         ...        ...            ...
# 609 -2.117107 -1.372089   -0.737806   0.528362      -0.392601
# 610  0.472343  0.728816    2.236021   0.528362      -0.392601
# 611  0.472343  0.728816    0.253470   0.528362      -0.392601
# 612  0.472343  0.728816    1.244745   0.528362      -0.392601
# 613 -2.117107 -1.372089   -0.737806   0.528362       2.547117
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.072991          -0.554487    0.000000          0.279851
# 1          -0.134412          -0.038732   -0.219273          0.279851
# 2          -0.393747          -0.554487   -0.957641          0.279851
# 3          -0.462062           0.251980   -0.314547          0.279851
# 4           0.097728          -0.554487   -0.064454          0.279851
# ..               ...                ...         ...               ...
# 609        -0.410130          -0.554487   -0.898095          0.279851
# 610        -0.212557          -0.554487   -1.267279         -2.518655
# 611         0.437174          -0.472404    1.269371          0.279851
# 612         0.357064          -0.554487    0.483367          0.279851
# 613        -0.134412          -0.554487   -0.159728          0.279851
#
#      Credit_History  Property_Area
# 0          0.451640       1.223298
# 1          0.451640      -1.318513
# 2          0.451640       1.223298
# 3          0.451640       1.223298
# 4          0.451640       1.223298
# ..              ...            ...
# 609        0.451640      -1.318513
# 610        0.451640      -1.318513
# 611        0.451640       1.223298
# 612        0.451640       1.223298
# 613       -2.410441      -0.047607
#
# [614 rows x 11 columns]

# %%
X_scaled_df
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.472343 -1.372089   -0.737806   0.528362      -0.392601
# 1    0.472343  0.728816    0.253470   0.528362      -0.392601
# 2    0.472343  0.728816   -0.737806   0.528362       2.547117
# 3    0.472343  0.728816   -0.737806  -1.892641      -0.392601
# 4    0.472343 -1.372089   -0.737806   0.528362      -0.392601
# ..        ...       ...         ...        ...            ...
# 609 -2.117107 -1.372089   -0.737806   0.528362      -0.392601
# 610  0.472343  0.728816    2.236021   0.528362      -0.392601
# 611  0.472343  0.728816    0.253470   0.528362      -0.392601
# 612  0.472343  0.728816    1.244745   0.528362      -0.392601
# 613 -2.117107 -1.372089   -0.737806   0.528362       2.547117
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.072991          -0.554487    0.000000          0.279851
# 1          -0.134412          -0.038732   -0.219273          0.279851
# 2          -0.393747          -0.554487   -0.957641          0.279851
# 3          -0.462062           0.251980   -0.314547          0.279851
# 4           0.097728          -0.554487   -0.064454          0.279851
# ..               ...                ...         ...               ...
# 609        -0.410130          -0.554487   -0.898095          0.279851
# 610        -0.212557          -0.554487   -1.267279         -2.518655
# 611         0.437174          -0.472404    1.269371          0.279851
# 612         0.357064          -0.554487    0.483367          0.279851
# 613        -0.134412          -0.554487   -0.159728          0.279851
#
#      Credit_History  Property_Area
# 0          0.451640       1.223298
# 1          0.451640      -1.318513
# 2          0.451640       1.223298
# 3          0.451640       1.223298
# 4          0.451640       1.223298
# ..              ...            ...
# 609        0.451640      -1.318513
# 610        0.451640      -1.318513
# 611        0.451640       1.223298
# 612        0.451640       1.223298
# 613       -2.410441      -0.047607
#
# [614 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled_df,
                                               y,
                                              test_size=0.2,
                                              random_state=1234)

# %%
X_scaled_df.shape,X_train.shape,X_test.shape
# Out:
# ((614, 11), (491, 11), (123, 11))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([0.78054078, 0.78485093, 0.8495364 , 0.75896259, 0.86669106,
#        0.14014994, 0.72904818, 0.85416495, 0.09301672, 0.82339954,
#        0.8282505 , 0.90060068, 0.8946641 , 0.58611305, 0.67428593,
#        0.70117935, 0.79557351, 0.91392266, 0.77683543, 0.83160669,
#        0.15279425, 0.80566344, 0.74229232, 0.75910644, 0.79261156,
#        0.70172152, 0.10266336, 0.91642013, 0.11962874, 0.6809678 ,
#        0.83770606, 0.12197757, 0.7137883 , 0.8392646 , 0.10738585,
#        0.02607315, 0.05515518, 0.79296655, 0.06608803, 0.81358475,
#        0.81210435, 0.84290459, 0.10761083, 0.76240187, 0.74183651,
#        0.05953334, 0.77957909, 0.66856367, 0.70691579, 0.82246969,
#        0.76306731, 0.82679315, 0.86210984, 0.75295352, 0.58048558,
#        0.75731571, 0.16366028, 0.62033222, 0.78465309, 0.11784008,
#        0.85050576, 0.09650529, 0.73847393, 0.73261707, 0.77431366,
#        0.81652492, 0.87441312, 0.70697903, 0.71769068, 0.82784062,
#        0.71185764, 0.83242887, 0.70898223, 0.86023967, 0.04555889,
#        0.78889551, 0.67464081, 0.82893972, 0.79725889, 0.69672926,
#        0.76669486, 0.80286542, 0.90434468, 0.6897062 , 0.80394656,
#        0.78840448, 0.85074288, 0.78405249, 0.65709585, 0.91488481,
#        0.79807398, 0.83220021, 0.18708829, 0.78614613, 0.72696024,
#        0.18426671, 0.72682221, 0.7958674 , 0.82307267, 0.82228809,
#        0.74294794, 0.7186125 , 0.84734673, 0.17332121, 0.85268591,
#        0.73118535, 0.86585964, 0.7717125 , 0.81956994, 0.80825867,
#        0.76160442, 0.80992574, 0.12476883, 0.83358221, 0.84326251,
#        0.12152159, 0.86523771, 0.82724777, 0.7715146 , 0.70144167,
#        0.73025173, 0.11292315, 0.78768342])

# %%
eval_df=X_test
eval_df['y_actual']=y_test
eval_df['y_pred']=y_pred
eval_df
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 163  0.472343  0.728816    1.244745   0.528362      -0.392601
# 290  0.472343  0.728816   -0.737806   0.528362      -0.392601
# 568 -2.117107 -1.372089   -0.737806   0.528362      -0.392601
# 356  0.472343  0.728816    1.244745   0.528362      -0.392601
# 435 -2.117107  0.728816   -0.737806   0.528362      -0.392601
# ..        ...       ...         ...        ...            ...
# 21   0.472343  0.728816    0.253470   0.528362      -0.392601
# 95   0.472343 -1.372089   -0.737806   0.528362      -0.392601
# 518  0.472343 -1.372089   -0.737806   0.528362      -0.392601
# 78   0.472343  0.728816    2.236021   0.528362      -0.392601
# 59   0.472343  0.728816    1.244745  -1.892641      -0.392601
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 163        -0.202563          -0.059594    0.138001          0.279851
# 290        -0.381460           0.271816   -0.088273          0.279851
# 568        -0.495647          -0.554487   -1.636463          0.279851
# 356         0.479933           0.528668    0.221365          0.279851
# 435         0.760729          -0.554487    0.000000         -1.585820
# ..               ...                ...         ...               ...
# 21          0.090356           1.369336    2.007739          0.279851
# 95          0.225840          -0.554487    0.000000          0.279851
# 518        -0.118029           0.100468    0.459549          0.279851
# 78         -0.366389           0.813565    0.400003         -0.652985
# 59         -0.335262           0.423328   -0.028727          0.279851
#
#      Credit_History  Property_Area  y_actual    y_pred
# 163    4.516405e-01      -1.318513         1  0.780541
# 290    4.516405e-01      -1.318513         1  0.784851
# 568    4.516405e-01       1.223298         0  0.849536
# 356    4.516405e-01      -1.318513         1  0.758963
# 435    4.516405e-01      -0.047607         1  0.866691
# ..              ...            ...       ...       ...
# 21     4.516405e-01       1.223298         1  0.771515
# 95     3.177548e-16       1.223298         0  0.701442
# 518    4.516405e-01      -0.047607         0  0.730252
# 78    -2.410441e+00      -0.047607         0  0.112923
# 59     4.516405e-01       1.223298         1  0.787683
#
# [123 rows x 13 columns]

# %%
#import numpy as np
#con1=eval_df['y_actual']==eval_df['y_pred']
#eval_df['correct_prediction']=np.where(con1,1,0)
#eval_df

# %%
import pickle
path=open('lr_Loan1.pkl','wb')
pickle.dump(lr,path)

# %%
with open('lr_Loan1.pkl','wb') as file:
    pickle.dump(lr,file)

# %%
test=pd.read_csv('test_lAUu6dG.csv')
test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               NaN         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
test_loan_data=test['Loan_ID']
input_data=test.drop('Loan_ID',axis=1)
input_data
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                    0       110.0             360.0             1.0
# 1                 1500       126.0             360.0             1.0
# 2                 1800       208.0             360.0             1.0
# 3                 2546       100.0             360.0             NaN
# 4                    0        78.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 362               1777       113.0             360.0             1.0
# 363                709       115.0             360.0             1.0
# 364               1993       126.0             360.0             NaN
# 365               2393       158.0             360.0             1.0
# 366                  0        98.0             180.0             1.0
#
#     Property_Area
# 0           Urban
# 1           Urban
# 2           Urban
# 3           Urban
# 4           Urban
# ..            ...
# 362         Urban
# 363         Urban
# 364     Semiurban
# 365         Rural
# 366         Rural
#
# [367 rows x 11 columns]

# %%
missing=input_data.isnull().sum()
print(missing)
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
input_data["Gender"]=input_data["Gender"].fillna(input_data["Gender"].mode()[0])
input_data["Dependents"]=input_data["Dependents"].fillna(input_data["Dependents"].mode()[0])
input_data["Self_Employed"]=input_data["Self_Employed"].fillna(input_data["Self_Employed"].mode()[0])
input_data["LoanAmount"]=input_data["LoanAmount"].fillna(input_data["LoanAmount"].mean())
input_data["Loan_Amount_Term"]=input_data["Loan_Amount_Term"].fillna(input_data["Loan_Amount_Term"].mean())
input_data["Credit_History"]=input_data["Credit_History"].fillna(input_data["Credit_History"].mean())

# %%
input_data.replace('3+', '3', inplace=True)
d={'Male':1,'Female':0}
input_data['Gender']=input_data['Gender'].map(d)
d={'Yes':1,'No':0}
input_data['Married']=input_data['Married'].map(d)
d={'0':0,'1':1,'2':2,'3':3}
input_data['Dependents']=input_data['Dependents'].map(d)
d={'Graduate':1,'Not Graduate':0}
input_data['Education']=input_data['Education'].map(d)
d={'Yes':1,'No':0}
input_data['Self_Employed']=input_data['Self_Employed'].map(d)
d={'Urban':2,'Rural':0,'Semiurban':1}
input_data['Property_Area']=input_data['Property_Area'].map(d)

# %%
input_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1           0          1              0             5720
# 1         1        1           1          1              0             3076
# 2         1        1           2          1              0             5000
# 3         1        1           2          1              0             2340
# 4         1        0           0          0              0             3276
# ..      ...      ...         ...        ...            ...              ...
# 362       1        1           3          0              1             4009
# 363       1        1           0          1              0             4158
# 364       1        0           0          1              0             3250
# 365       1        1           0          1              0             5000
# 366       1        0           0          1              1             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                    0       110.0             360.0        1.000000
# 1                 1500       126.0             360.0        1.000000
# 2                 1800       208.0             360.0        1.000000
# 3                 2546       100.0             360.0        0.825444
# 4                    0        78.0             360.0        1.000000
# ..                 ...         ...               ...             ...
# 362               1777       113.0             360.0        1.000000
# 363                709       115.0             360.0        1.000000
# 364               1993       126.0             360.0        0.825444
# 365               2393       158.0             360.0        1.000000
# 366                  0        98.0             180.0        1.000000
#
#      Property_Area
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# ..             ...
# 362              2
# 363              2
# 364              1
# 365              0
# 366              0
#
# [367 rows x 11 columns]

# %%
prediction=lr.predict(input_data)

# %%
prediction
# Out:
# array([ 5.42639277e+00, -5.16456826e+01, -6.11095409e+01, -8.87119855e+01,
#         2.20039860e+00, -1.20888098e+02,  9.42573295e-01,  1.12462887e+00,
#         1.46131413e+01, -8.41684671e+01,  1.58635172e+00, -5.46275202e+01,
#         5.66270741e+00,  1.42255765e+01,  3.26685522e+00,  4.74638074e+00,
#        -1.00519306e+02, -9.81356218e+00, -2.69979700e+02, -1.21620263e+02,
#        -5.57697703e+01,  2.58935805e+00,  2.66199883e+00,  1.77664475e+00,
#         5.80676601e+00, -1.62445459e+02,  3.75926154e+00, -1.85464619e+02,
#        -7.23601130e+01,  3.16056182e+00,  1.92276980e+00, -2.21617138e+01,
#         2.75490345e+00, -1.01459505e+02,  3.34771004e+00, -9.47089203e+01,
#        -5.44167671e+01, -6.45707482e+01,  3.80581389e+00, -1.50502242e+02,
#         5.24879780e+00, -8.13638115e+01, -2.16052004e+01, -2.11554677e+01,
#        -4.29036789e+01, -5.59680355e+01,  4.15784005e+00,  6.96513321e+00,
#        -9.44134148e+01,  3.66530966e+00, -6.75888773e+01,  1.61864135e+00,
#        -6.97884915e+01, -5.47618568e+01, -1.15885610e+02, -7.99308743e+01,
#        -1.67475273e+02, -1.48691388e+02,  3.53609200e+00,  4.53633099e+00,
#         5.45954314e+00,  5.77713652e+00, -6.78678775e+01,  1.74242887e+00,
#        -4.71662734e+01, -1.05744798e+01,  6.41596846e+00, -5.23577407e+02,
#        -2.61390516e+01, -1.27380627e+02, -2.26412543e+00, -3.60992473e+01,
#        -6.46243251e+01,  1.42818253e+00,  1.94221869e+00, -9.15999884e+01,
#        -1.38087117e+02, -7.55654081e+01, -5.94855207e+01, -2.19903222e+01,
#        -6.86733678e+01, -8.05545894e+01,  1.23627733e+01])

# %%
predict=pd.DataFrame(prediction, columns=['Loan_Status'])
predict['Loan_ID']=test_loan_data
predict
# Out:
#      Loan_Status   Loan_ID
# 0       5.426393  LP001015
# 1     -51.645683  LP001022
# 2     -61.109541  LP001031
# 3     -88.711985  LP001035
# 4       2.200399  LP001051
# ..           ...       ...
# 362   -59.485521  LP002971
# 363   -21.990322  LP002975
# 364   -68.673368  LP002980
# 365   -80.554589  LP002986
# 366    12.362773  LP002989
#
# [367 rows x 2 columns]

# %%
predict=predict[['Loan_ID', 'Loan_Status']]
predict
# Out:
#       Loan_ID  Loan_Status
# 0    LP001015     5.426393
# 1    LP001022   -51.645683
# 2    LP001031   -61.109541
# 3    LP001035   -88.711985
# 4    LP001051     2.200399
# ..        ...          ...
# 362  LP002971   -59.485521
# 363  LP002975   -21.990322
# 364  LP002980   -68.673368
# 365  LP002986   -80.554589
# 366  LP002989    12.362773
#
# [367 rows x 2 columns]

# %%
predict['Loan_Status'].value_counts()
# Out:
# Loan_Status
#  5.412994      2
#  5.426393      1
# -26.972929     1
#  3.752772      1
# -15.649084     1
#               ..
# -133.790800    1
#  2.318392      1
# -128.182146    1
# -94.171793     1
#  12.362773     1
# Name: count, Length: 366, dtype: int64

# %%
predict['Loan_Status'] = predict['Loan_Status'].apply(lambda x: 'Y' if x >= 0 else 'N')

# %%
predict
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           N
# 2    LP001031           N
# 3    LP001035           N
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           N
# 363  LP002975           N
# 364  LP002980           N
# 365  LP002986           N
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
predict['Loan_Status'].value_counts()
# Out:
# Loan_Status
# N    215
# Y    152
# Name: count, dtype: int64
