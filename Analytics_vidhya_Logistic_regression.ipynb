# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('train_ctrUa4K.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.replace('3+', '3', inplace=True)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data=data['Loan_ID']
data.drop("Loan_ID",axis=1,inplace=True)
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes          3      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
loan_data
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cat=data.select_dtypes(include='object').columns
num=data.select_dtypes(exclude='object').columns

cat
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data["Gender"]=data["Gender"].fillna(data["Gender"].mode()[0])
data["Married"]=data["Married"].fillna(data["Married"].mode()[0])
data["Dependents"]=data["Dependents"].fillna(data["Dependents"].mode()[0])
data["Education"]=data["Education"].fillna(data["Education"].mode()[0])
data["Self_Employed"]=data["Self_Employed"].fillna(data["Self_Employed"].mode()[0])
data["Property_Area"]=data["Property_Area"].fillna(data["Property_Area"].mode()[0])

# %%
cat
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
num
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
data["LoanAmount"]=data["LoanAmount"].fillna(data["LoanAmount"].mean())
data["Loan_Amount_Term"]=data["Loan_Amount_Term"].fillna(data["Loan_Amount_Term"].mean())
data["Credit_History"]=data["Credit_History"].fillna(data["Credit_History"].mean())

# %%
missing=data.isnull().sum()
print(missing)
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
cat=data.select_dtypes(include='object').columns
num=data.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
num
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes          3      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
for i in cat:
    unique=data[i].unique()
    print(f'{i} : {unique}')
# Out:
# Gender : ['Male' 'Female']
# Married : ['No' 'Yes']
# Dependents : ['0' '1' '2' '3']
# Education : ['Graduate' 'Not Graduate']
# Self_Employed : ['No' 'Yes']
# Property_Area : ['Urban' 'Rural' 'Semiurban']
# Loan_Status : ['Y' 'N']

# %%
# DEpendents comes under catigorical column because it is a string

# %%
d={'Male':1,'Female':0}
data['Gender']=data['Gender'].map(d)
d={'Yes':1,'No':0}
data['Married']=data['Married'].map(d)
d={'0':0,'1':1,'2':2,'3':3}
data['Dependents']=data['Dependents'].map(d)
d={'Graduate':1,'Not Graduate':0}
data['Education']=data['Education'].map(d)
d={'Yes':1,'No':0}
data['Self_Employed']=data['Self_Employed'].map(d)
d={'Urban':2,'Rural':0,'Semiurban':1}
data['Property_Area']=data['Property_Area'].map(d)
#d={'Y':1,'N':0}
#data['Loan_Status']=data['Loan_Status'].map(d)

# %%
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
# ...

# %%
X=data.drop('Loan_Status',axis=1)
y=data['Loan_Status']
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
# ...

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,
                                               y,
                                              test_size=0.2,
                                              random_state=1234)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((491, 11), (123, 11), (491,), (123,))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\dhana\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_pred=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_pred,y_train)

# %%
print('The accuracy on trained data :' ,training_data_accuracy )
# Out:
# The accuracy on trained data : 0.7983706720977597

# %%
X_test_pred=model.predict(X_test)
tested_data_accuracy=accuracy_score(X_test_pred,y_test)

# %%
print('The accuracy on tested data :' ,tested_data_accuracy )
# Out:
# The accuracy on tested data : 0.8455284552845529

# %%
test_data=pd.read_csv('test_lAUu6dG.csv')
test_data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
test_loan_data=test_data['Loan_ID']
input_data=test_data.drop('Loan_ID',axis=1)
input_data
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %%
missing=input_data.isnull().sum()
print(missing)
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
input_data["Gender"]=input_data["Gender"].fillna(input_data["Gender"].mode()[0])
input_data["Dependents"]=input_data["Dependents"].fillna(input_data["Dependents"].mode()[0])
input_data["Self_Employed"]=input_data["Self_Employed"].fillna(input_data["Self_Employed"].mode()[0])
input_data["LoanAmount"]=input_data["LoanAmount"].fillna(input_data["LoanAmount"].mean())
input_data["Loan_Amount_Term"]=input_data["Loan_Amount_Term"].fillna(input_data["Loan_Amount_Term"].mean())
input_data["Credit_History"]=input_data["Credit_History"].fillna(input_data["Credit_History"].mean())

# %%
input_data.replace('3+', '3', inplace=True)
d={'Male':1,'Female':0}
input_data['Gender']=input_data['Gender'].map(d)
d={'Yes':1,'No':0}
input_data['Married']=input_data['Married'].map(d)
d={'0':0,'1':1,'2':2,'3':3}
input_data['Dependents']=input_data['Dependents'].map(d)
d={'Graduate':1,'Not Graduate':0}
input_data['Education']=input_data['Education'].map(d)
d={'Yes':1,'No':0}
input_data['Self_Employed']=input_data['Self_Employed'].map(d)
d={'Urban':2,'Rural':0,'Semiurban':1}
input_data['Property_Area']=input_data['Property_Area'].map(d)

# %%
input_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1           0          1              0             5720
# 1         1        1           1          1              0             3076
# 2         1        1           2          1              0             5000
# 3         1        1           2          1              0             2340
# 4         1        0           0          0              0             3276
# ..      ...      ...         ...        ...            ...              ...
# 362       1        1           3          0              1             4009
# 363       1        1           0          1              0             4158
# 364       1        0           0          1              0             3250
# 365       1        1           0          1              0             5000
# 366       1        0           0          1              1             9200
#
# ...

# %%
prediction=model.predict(input_data)

# %%
prediction
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...

# %%
predict=pd.DataFrame(prediction, columns=['Loan_Status'])
predict['Loan_ID']=test_loan_data
predict
# Out:
#     Loan_Status   Loan_ID
# 0             Y  LP001015
# 1             Y  LP001022
# 2             Y  LP001031
# 3             Y  LP001035
# 4             Y  LP001051
# ..          ...       ...
# 362           Y  LP002971
# 363           Y  LP002975
# 364           Y  LP002980
# 365           Y  LP002986
# 366           Y  LP002989
#
# [367 rows x 2 columns]

# %%
predict=predict[['Loan_ID', 'Loan_Status']]
predict
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
predict['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    304
# N     63
# Name: count, dtype: int64

# %%
import pandas as pd

# Assuming you have the DataFrame 'predict'
# predict=pd.DataFrame(prediction, columns=['Loan_Status'])
# predict['Loan_ID']=test_loan_data

# Specify the file name for the CSV
csv_file_path = 'loan_prediction_result.csv'

# Convert DataFrame to CSV
predict.to_csv(csv_file_path, index=False)

print(f'DataFrame has been written to {csv_file_path}')
# Out:
# DataFrame has been written to loan_prediction_result.csv
